# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
d = pd.Series({"서울":123, "대전":234,"부산":12345})
print(d)

s = pd.Series([9904312, 3448737, 2890451, 2466052], index=["Seoul","Busan","Inchon","Daegu"])
s
# Out:
# 서울      123
# 대전      234
# 부산    12345
# dtype: int64
# Seoul     9904312
# Busan     3448737
# Inchon    2890451
# Daegu     2466052
# dtype: int64

# %%
pd.Series(range(10,14))
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
print(s.index)
print(s.values)
# Out:
# Index(['Seoul', 'Busan', 'Inchon', 'Daegu'], dtype='object')
# [9904312 3448737 2890451 2466052]

# %%
s.name = "인구"
s.index.name = "도시"
s
figure, axis = plt.subplots()
axis.plot(s)
plt.show()

# %%
s / 1e6
# Out:
# 도시
# Seoul     9.904312
# Busan     3.448737
# Inchon    2.890451
# Daegu     2.466052
# Name: 인구, dtype: float64

# %%
print(s[1])
print(s["Busan"])

s[1], s["Busan"]
# Out:
# 3448737
# 3448737
# (3448737, 3448737)

# %%
print(s[[0,3,1]])

print(s[(300e4 < s) & (s < 500e4)])
# Out:
# 도시
# Seoul    9904312
# Daegu    2466052
# Busan    3448737
# Name: 인구, dtype: int64
# 도시
# Busan    3448737
# Name: 인구, dtype: int64

# %%
# s["Busan":"Daegu"]
s.Busan

"Dajeon" in 천천
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-41784fcfd2e4> in <module>
#       2 s.Busan
#       3
# ----> 4 "Dajeon" in 천천
#
# NameError: name '천천' is not defined

# %%
s2 = pd.Series({"Seoul":9631482, "Busan":3393191, "Inchon":2632035, "Daejeon":1490158}, index=["Busan","Seoul","Inchon","Daejeon"])
s2
# Out:
# Busan      3393191
# Seoul      9631482
# Inchon     2632035
# Daejeon    1490158
# dtype: int64

# %%
print(s),print(s2)

ds = s - s2
ds
# Out:
# 도시
# Seoul     9904312
# Busan     3448737
# Inchon    2890451
# Daegu     2466052
# Name: 인구, dtype: int64
# Busan      3393191
# Seoul      9631482
# Inchon     2632035
# Daejeon    1490158
# dtype: int64
# Busan       55546.0
# Daegu           NaN
# Daejeon         NaN
# Inchon     258416.0
# Seoul      272830.0
# dtype: float64

# %%
s.values - s2.values
# Out:
# array([ 6511121, -6182745,   258416,   975894], dtype=int64)

# %%
ds[ds.notnull()]
# Out:
# Busan      55546.0
# Inchon    258416.0
# Seoul     272830.0
# dtype: float64

# %%
rs = (s - s2) / s2 * 100
rs = rs[rs.notnull()]
rs
# Out:
# Busan     1.636984
# Inchon    9.818107
# Seoul     2.832690
# dtype: float64

# %%
# rs.Busan = 1.63
# rs["Daegu"] = 1.41

# del rs["Seoul"]

rs
# Out:
# Busan     1.630000
# Inchon    9.818107
# Daegu     1.410000
# dtype: float64

# %%
shop1 = pd.Series([1000,1200,3200,5000],index=["사과","배","딸기","바나나"])
shop2 = pd.Series([1200,1000,3000,2500],index=["사과","배","바나나","키위"])

shop1.name = "철수네 과일"
shop1.index.name = "가격표"

shop2.name = "영희네 과일"
shop2.index.name = "가격표"

print(shop1), print(shop2)

sub = shop1 - shop2
sub = sub[sub.notnull()]
sub.name = "가격 비교"
print(sub)

sum1 = shop1 + shop2
sum1 = sum1[sum1.notnull()]
sum1
# Out:
# 가격표
# 사과     1000
# 배      1200
# 딸기     3200
# 바나나    5000
# Name: 철수네 과일, dtype: int64
# 가격표
# 사과     1200
# 배      1000
# 바나나    3000
# 키위     2500
# Name: 영희네 과일, dtype: int64
# 가격표
# 바나나    2000.0
# 배       200.0
# 사과     -200.0
# Name: 가격 비교, dtype: float64
# 가격표
# 바나나    8000.0
# 배      2200.0
# 사과     2200.0
# dtype: float64

# %%
data = {
    "2015" : [9904312, 3448737, 2890451, 2466052],
    "2010" : [9631482, 3393191, 2632035, 2431774],
    "2005" : [9762546, 3512547, 2466338, 2473990],
    "2000" : [9853972, 3655437, 2466338, 2473990],
    "지역" : ["수도권", "경상권", "수도권", "경상권"],
    "2010-2015 증가율" : [0.0283, 0.0163, 0.0982, 0.0141]
}

column = ["지역", "2015", "2010", "2005", "2000", "2010-2015 증가율"]
index = ["서울","부산","인천","대구"]

df = pd.DataFrame(data, index=index, columns=column)
df
# Out:
#      지역     2015     2010     2005     2000  2010-2015 증가율
# 서울  수도권  9904312  9631482  9762546  9853972         0.0283
# 부산  경상권  3448737  3393191  3512547  3655437         0.0163
# 인천  수도권  2890451  2632035  2466338  2466338         0.0982
# 대구  경상권  2466052  2431774  2473990  2473990         0.0141

# %%
print(df.values)
print(df.index)
# Out:
# [['수도권' 9904312 9631482 9762546 9853972 0.0283]
#  ['경상권' 3448737 3393191 3512547 3655437 0.0163]
#  ['수도권' 2890451 2632035 2466338 2466338 0.0982]
#  ['경상권' 2466052 2431774 2473990 2473990 0.0141]]
# Index(['서울', '부산', '인천', '대구'], dtype='object')

# %%
df.index.name = "도시"
df.columns.name = "특성"
df
# Out:
# 특성   지역     2015     2010     2005     2000  2010-2015 증가율
# 도시
# 서울  수도권  9904312  9631482  9762546  9853972         0.0283
# 부산  경상권  3448737  3393191  3512547  3655437         0.0163
# 인천  수도권  2890451  2632035  2466338  2466338         0.0982
# 대구  경상권  2466052  2431774  2473990  2473990         0.0141

# %%
df["2005-2010 증가율"] = ((df["2010"] - df["2005"]) / df["2005"] * 100).round(2)
# del df["2005-2010 증가율"]
df[1:2]
# Out:
# 특성   지역     2015     2010     2005     2000  2010-2015 증가율  2005-2010 증가율
# 도시
# 부산  경상권  3448737  3393191  3512547  3655437         0.0163           -3.4

# %%
exData = {
    "철수네" : [100,200,300,400],
    "영희네" : [200,300,400,560],
    "삼룡네" : [300,500,200,100]    
}

columns = ["철수네","삼룡네","영희네"]
index = ["사과","딸기","바나나","파인애플"]

shops = pd.DataFrame(exData, index=index, columns=columns)
shops.columns.name = "과일가게"
shops.index.name = "품목"

shops.mean()
# Out:
# 과일가게
# 철수네    250.0
# 삼룡네    275.0
# 영희네    365.0
# dtype: float64

# %%
shops["평균"] = shops.T.mean()

# %%
# %%writefile sample.csv
# c1,c2,c3
# 1,1.11,one
# 2,2.22,two
# 3,3.33,three
# Out:
# Overwriting sample.csv

# %%
pd.read_csv('sample.csv')
# Out:
#    c1    c2     c3
# 0   1  1.11    one
# 1   2  2.22    two
# 2   3  3.33  three

# %%
sa = pd.read_csv("sample.csv", index_col="c3")
# sa["c1"].two
sa
# Out:
#        c1    c2
# c3
# one     1  1.11
# two     2  2.22
# three   3  3.33

# %%
# %%writefile sample3.txt
# c1  c2  c3  c4
# 0.179181    -1.538472   1.347553    0.43381
# 1.024209    0.087307    -1.281997   0.49265
# 0.417899    -2.002308   0.255245    -1.10515
# Out:
# Overwriting sample3.txt

# %%
pd.read_table("sample3.txt","\s+")
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417899 -2.002308  0.255245 -1.10515

# %%
data = { "국어": [80, 90, 70, 30], "영어": [90, 70, 60, 40], "수학": [90, 60, 80, 70], }
columns = ["국어", "영어", "수학"]
index = ["춘향", "몽룡", "향단", "방자"]
df = pd.DataFrame(data, index=index, columns=columns)

# (1) 모든 학생의 수학 점수를 시리즈로 나타낸다.

print(df["수학"])

# (2) 모든 학생의 국어와 영어 점수를 데이터 프레임으로 나타낸다.

print(df[["국어","영어"]])

# (3) 모든 학생의 각 과목 평균 점수를 새로운 열로 추가한다.
df["평균"] = df.mean(axis=1)
df

# (4) 방자의 영어 점수를 80점으로 수정하고 평균 점수도 다시 계산한다.
df["영어"]["방자"] = 80
del df["평균"]
df["평균"] = df.mean(axis=1)

# (5) 춘향의 점수를 데이터프레임으로 나타낸다.
print(df[:1])
 
# (6) 향단의 점수를 시리즈로 나타낸다.
df[2:3].T["향단"]
# Out:
# 춘향    90
# 몽룡    60
# 향단    80
# 방자    70
# Name: 수학, dtype: int64
#     국어  영어
# 춘향  80  90
# 몽룡  90  70
# 향단  70  60
# 방자  30  40
#     국어  영어  수학         평균
# 춘향  80  90  90  86.666667
# <ipython-input-56-6507fe3f7e3a>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["영어"]["방자"] = 80
# 국어    70.0
# 영어    60.0
# 수학    80.0
# 평균    70.0
# Name: 향단, dtype: float64

# %%
df.to_csv("sample7.csv")

# %%
df2 = pd.DataFrame(np.arange(10, 22).reshape(3, 4),
                  index=["a", "b", "c"],
                  columns=["A", "B", "C", "D"])
print(df2)
print(df2.loc["b":"c"])
df[["국어"]] #<----- DataFrame
df["국어"] # <--- Series

#loc, iloc 는 행 기반으로 인덱싱이 가능한거다.abs

df.loc[["방자","춘향"]]


df2["b":"c"]
df["향단":"방자"]

df2.loc[lambda x : x.A > 15]

df2.loc["a",:]

df2.loc[df2.A > 10, ["C","D"]]
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21
#     C   D
# b  16  17
# c  20  21

# %%
s = pd.Series(np.arange(10))
s[3] = np.nan
s

s.count()
# Out:
# 9

# %%
np.random.seed(2)
df = pd.DataFrame(np.random.randint(5, size=(4,4)), dtype=float)
df.iloc[2,3] = np.nan
print(df)
df.count()
# Out:
#      0    1    2    3
# 0  0.0  0.0  3.0  2.0
# 1  3.0  0.0  2.0  1.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.count()

titanic.sex.count()

titanic["class"].value_counts().sort_index()
# Out:
# First     216
# Second    184
# Third     491
# Name: class, dtype: int64

# %%
# titanic[["sex","age","class","alive"]].value_counts().sort_index()
titanic[["sex","age","class","alive"]].value_counts().sort_index()

print(titanic["sex"].value_counts())
print(titanic["age"].value_counts())
print(titanic["class"].value_counts())
print(titanic["alive"].value_counts())
# Out:
# male      577
# female    314
# Name: sex, dtype: int64
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: age, Length: 88, dtype: int64
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
titanic["age"].mean().round(2)
# Out:
# 29.7

# %%
np.random.seed(1)
df2 = pd.DataFrame(np.random.randint(10, size=(4, 8)))

df2.sum(axis=0)
df2["Row Sum"] = df2.sum(axis=1)
df2.loc["Col Sum"] = df2.sum(axis=0)

df2["Row Mean"] = df2.iloc[:,:-1].mean(axis=1)
df2.loc["Col Mean"] = df2[:-1].mean(axis=0)

df2
# Out:
#              0      1      2     3      4     5     6     7  Row Sum  Row Mean
# 0          5.0   8.00   9.00   5.0   0.00   0.0  1.00   7.0     35.0     4.375
# 1          6.0   9.00   2.00   4.0   5.00   2.0  4.00   2.0     34.0     4.250
# 2          4.0   7.00   7.00   9.0   1.00   7.0  0.00   6.0     41.0     5.125
# 3          9.0   9.00   7.00   6.0   9.00   1.0  0.00   1.0     42.0     5.250
# Col Sum   24.0  33.00  25.00  24.0  15.00  10.0  5.00  16.0    152.0    19.000
# Col Mean   6.0   8.25   6.25   6.0   3.75   2.5  1.25   4.0     38.0     4.750

# %%
df2.apply(lambda x: x.max()-x.min(), axis=1)
df2.apply(df2.value_counts)
# Out:
#            0    1    2    3    4    5    6    7  Row Sum  Row Mean
# 0.000    NaN  NaN  NaN  NaN  1.0  1.0  2.0  NaN      NaN       NaN
# 1.000    NaN  NaN  NaN  NaN  1.0  1.0  1.0  1.0      NaN       NaN
# 1.250    NaN  NaN  NaN  NaN  NaN  NaN  1.0  NaN      NaN       NaN
# 2.000    NaN  NaN  1.0  NaN  NaN  1.0  NaN  1.0      NaN       NaN
# 2.500    NaN  NaN  NaN  NaN  NaN  1.0  NaN  NaN      NaN       NaN
# 3.750    NaN  NaN  NaN  NaN  1.0  NaN  NaN  NaN      NaN       NaN
# 4.000    1.0  NaN  NaN  1.0  NaN  NaN  1.0  1.0      NaN       NaN
# 4.250    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN       1.0
# 4.375    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN       1.0
# 4.750    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN       1.0
# 5.000    1.0  NaN  NaN  1.0  1.0  NaN  1.0  NaN      NaN       NaN
# 5.125    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN       1.0
# 5.250    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN       1.0
# 6.000    2.0  NaN  NaN  2.0  NaN  NaN  NaN  1.0      NaN       NaN
# 6.250    NaN  NaN  1.0  NaN  NaN  NaN  NaN  NaN      NaN       NaN
# 7.000    NaN  1.0  2.0  NaN  NaN  1.0  NaN  1.0      NaN       NaN
# 8.000    NaN  1.0  NaN  NaN  NaN  NaN  NaN  NaN      NaN       NaN
# 8.250    NaN  1.0  NaN  NaN  NaN  NaN  NaN  NaN      NaN       NaN
# 9.000    1.0  2.0  1.0  1.0  1.0  NaN  NaN  NaN      NaN       NaN
# 10.000   NaN  NaN  NaN  NaN  NaN  1.0  NaN  NaN      NaN       NaN
# 15.000   NaN  NaN  NaN  NaN  1.0  NaN  NaN  NaN      NaN       NaN
# 16.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  1.0      NaN       NaN
# 19.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN       1.0
# 24.000   1.0  NaN  NaN  1.0  NaN  NaN  NaN  NaN      NaN       NaN
# 25.000   NaN  NaN  1.0  NaN  NaN  NaN  NaN  NaN      NaN       NaN
# 33.000   NaN  1.0  NaN  NaN  NaN  NaN  NaN  NaN      NaN       NaN
# 34.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1.0       NaN
# 35.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1.0       NaN
# 38.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1.0       NaN
# 41.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1.0       NaN
# 42.000   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1.0       NaN
# 152.000  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1.0       NaN

# %%
titanic["adult/child"] = titanic.apply(lambda r : "adult" if r.age > 20 else "child", axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child
# 886    man        True  NaN  Southampton    no   True       adult
# 887  woman       False    B  Southampton   yes   True       child
# 888  woman       False  NaN  Southampton    no  False       child
# 889    man        True    C    Cherbourg   yes   True       adult
# 890    man        True  NaN   Queenstown    no   True       adult

# %%
titanic["category1"] = titanic.apply(lambda r : r.sex if r.age > 30 else "child", axis = 1)
titanic.category1.value_counts()
# Out:
# child     586
# male      202
# female    103
# Name: category1, dtype: int64
